# %%
import re

import parse
import pdfplumber
import pandas as pd
from collections import namedtuple

# %%
file = 'bluesign-reference-list-total_august_2020_new.pdf'

# %%
with pdfplumber.open(file) as pdf:
    pages = pdf.pages

# %%
for page in pdf.pages:
        table = page.extract_table()
pd.DataFrame(table[1::],columns=table[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-729cdf9ee048> in <module>
#       1 for page in pdf.pages:
# ----> 2         table = page.extract_table()
#       3 pd.DataFrame(table[1::],columns=table[0])
#       4
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\page.py in extract_table(self, table_settings)
#     283     ) -> Optional[List[List[Optional[str]]]]:
#     284         tset = TableSettings.resolve(table_settings)
# --> 285         tables = self.find_tables(tset)
#     286
#     287         if len(tables) == 0:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\page.py in find_tables(self, table_settings)
#     265     ) -> List[Table]:
#     266         tset = TableSettings.resolve(table_settings)
# --> 267         return TableFinder(self, tset).tables
#     268
#     269     def extract_tables(
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\table.py in __init__(self, page, settings)
#     559         self.page = page
#     560         self.settings = TableSettings.resolve(settings)
# --> 561         self.edges = self.get_edges()
#     562         self.intersections = edges_to_intersections(
#     563             self.edges,
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\table.py in get_edges(self)
#     614
#     615         if v_strat == "lines":
# --> 616             v_base = utils.filter_edges(self.page.edges, "v")
#     617         elif v_strat == "lines_strict":
#     618             v_base = utils.filter_edges(self.page.edges, "v", edge_type="line")
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\container.py in edges(self)
#      78         if hasattr(self, "_edges"):
#      79             return self._edges
# ---> 80         line_edges = list(map(utils.line_to_edge, self.lines))
#      81         self._edges: T_obj_list = self.rect_edges + line_edges
#      82         return self._edges
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\container.py in lines(self)
#      36     @property
#      37     def lines(self) -> T_obj_list:
# ---> 38         return self.objects.get("line", [])
#      39
#      40     @property
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\page.py in objects(self)
#     190         if hasattr(self, "_objects"):
#     191             return self._objects
# --> 192         self._objects: Dict[str, T_obj_list] = self.parse_objects()
#     193         return self._objects
#     194
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\page.py in parse_objects(self)
#     246     def parse_objects(self) -> Dict[str, T_obj_list]:
#     247         objects: Dict[str, T_obj_list] = {}
# --> 248         for obj in self.iter_layout_objects(self.layout._objs):
#     249             kind = obj["object_type"]
#     250             if kind in ["anno"]:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfplumber\page.py in layout(self)
#     136         )
#     137         interpreter = PDFPageInterpreter(self.pdf.rsrcmgr, device)
# --> 138         interpreter.process_page(self.page_obj)
#     139         self._layout: LTPage = device.get_result()
#     140         return self._layout
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdfinterp.py in process_page(self, page)
#     989             ctm = (1, 0, 0, 1, -x0, -y0)
#     990         self.device.begin_page(page, ctm)
# --> 991         self.render_contents(page.resources, page.contents, ctm=ctm)
#     992         self.device.end_page(page)
#     993         return
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdfinterp.py in render_contents(self, resources, streams, ctm)
#    1006             "render_contents: resources=%r, streams=%r, ctm=%r", resources, streams, ctm
#    1007         )
# -> 1008         self.init_resources(resources)
#    1009         self.init_state(ctm)
#    1010         self.execute(list_value(streams))
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdfinterp.py in init_resources(self, resources)
#     381                     if isinstance(spec, PDFObjRef):
#     382                         objid = spec.objid
# --> 383                     spec = dict_value(spec)
#     384                     self.fontmap[fontid] = self.rsrcmgr.get_font(objid, spec)
#     385             elif k == "ColorSpace":
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdftypes.py in dict_value(x)
#     203
#     204 def dict_value(x: object) -> Dict[Any, Any]:
# --> 205     x = resolve1(x)
#     206     if not isinstance(x, dict):
#     207         if settings.STRICT:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdftypes.py in resolve1(x, default)
#     116     """
#     117     while isinstance(x, PDFObjRef):
# --> 118         x = x.resolve(default=default)
#     119     return x
#     120
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdftypes.py in resolve(self, default)
#     104         assert self.doc is not None
#     105         try:
# --> 106             return self.doc.getobj(self.objid)
#     107         except PDFObjectNotFound:
#     108             return default
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdfdocument.py in getobj(self, objid)
#     861                 try:
#     862                     if strmid is not None:
# --> 863                         stream = stream_value(self.getobj(strmid))
#     864                         obj = self._getobj_objstm(stream, index, objid)
#     865                     else:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdfdocument.py in getobj(self, objid)
#     864                         obj = self._getobj_objstm(stream, index, objid)
#     865                     else:
# --> 866                         obj = self._getobj_parse(index, objid)
#     867                         if self.decipher:
#     868                             obj = decipher_all(self.decipher, objid, genno, obj)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\pdfdocument.py in _getobj_parse(self, pos, objid)
#     816     def _getobj_parse(self, pos: int, objid: int) -> object:
#     817         assert self._parser is not None
# --> 818         self._parser.seek(pos)
#     819         (_, objid1) = self._parser.nexttoken()  # objid
#     820         (_, genno) = self._parser.nexttoken()  # genno
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\psparser.py in seek(self, pos)
#     553
#     554     def seek(self, pos: int) -> None:
# --> 555         PSBaseParser.seek(self, pos)
#     556         self.reset()
#     557         return
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pdfminer\psparser.py in seek(self, pos)
#     218         """Seeks the parser to the given position."""
#     219         log.debug("seek: %r", pos)
# --> 220         self.fp.seek(pos)
#     221         # reset the status for nextline()
#     222         self.bufpos = pos
#
# ValueError: seek of closed file

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-1304ec6bf757> in <module>
# ----> 1 print(text[2])
#
# TypeError: 'method' object is not subscriptable
