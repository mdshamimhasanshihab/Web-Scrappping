# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
driver.get("https://www.greenseal.org/certified-products-services")
driver.maximize_window()
# Out:
# <ipython-input-2-a34289851f72>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

# %%
from selenium.webdriver.common.by import By
links=driver.find_elements(By.TAG_NAME,"a")

# %%
clk=driver.find_element(By.LINK_TEXT,"BROWSE BY COMPANY")
driver.execute_script("arguments[0].click();", clk)

# %%
links1=driver.find_elements(By.TAG_NAME,"a")

# %%
for x in range(7):    
    k=252
    links1=driver.find_elements(By.TAG_NAME,"a")
    for i in range(len(links1)-200):
        company_link=links1[k].get_attribute('href')
        k=k+2
        if company_link==None :
            break
        print(company_link)
    
    clk=driver.find_element(By.CSS_SELECTOR,"#app > main > div > div:nth-child(3) > div:nth-child(3) > div > a:nth-child(3) > img")
    driver.execute_script("arguments[0].click();", clk)
    time.sleep(5)
# Out:
# https://certified.greenseal.org/company/3m
# https://certified.greenseal.org/company/abc-compounding
# https://certified.greenseal.org/company/abco-cleaning-products
# https://certified.greenseal.org/company/accor-live-limitless
# https://certified.greenseal.org/company/ace-janitorial
# https://certified.greenseal.org/company/acme-paper-supply
# https://certified.greenseal.org/company/afflink-strategic-brands
# https://certified.greenseal.org/company/airlie
# https://certified.greenseal.org/company/airlite-am-technology
# https://certified.greenseal.org/company/al-bahar-industries
# https://certified.greenseal.org/company/alco-soap-supply
# https://certified.greenseal.org/company/alkavie-solutions
# https://certified.greenseal.org/company/almadion-international-gen-trading-llc
# https://certified.greenseal.org/company/american-cleaning-solutions
# https://certified.greenseal.org/company/american-formula
# https://certified.greenseal.org/company/american-hotel-register-co
# ...

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
driver.get("https://certified.greenseal.org/company/3m")
driver.maximize_window()
# Out:
# <ipython-input-63-638b177cbc03>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

# %%
from selenium.webdriver.common.by import By
links=driver.find_elements(By.TAG_NAME,"a")

# %%
len(links)
# Out:
# 334

# %%
import pandas as pd
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
df = pd.read_excel (r'C:\Users\User\OneDrive\Desktop\Data_acq\green_seal\companylink.xlsx')
for i in range(len(df)):
    URL=df.WebLink[i]

    driver.get(URL)
    time.sleep(4)
#     driver.maximize_window()

    for zz in range(100):

        links=driver.find_elements(By.TAG_NAME,"a")
        k=259
        for link in links:
            try:
                print(links[k].get_dom_attribute("href"))
                k=k+3
                if links[k].get_dom_attribute("href")==None :
                    break
            except:
                break
        try:
            clk=driver.find_element(By.CSS_SELECTOR,"#index-table > div > div:nth-child(4) > div > a:nth-child(3) > img")
            driver.execute_script("arguments[0].click();", clk)
            time.sleep(5)
        except:
            break
# Out:
# <ipython-input-80-679c4c57b299>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
# https://certified.greenseal.org/product/3m-3-in-1-floor-cleaner-concentrate-24a-3m-flow-control-system-3m
# https://certified.greenseal.org/product/3m-3-in-1-floor-cleaner-concentrate-24h-3m-twist-n-fill-dispensing-system-3m
# https://certified.greenseal.org/product/3m-bathroom-cleaner-concentrate-44a-3m-flow-control-system-3m
# https://certified.greenseal.org/product/3m-bathroom-cleaner-concentrate-44l-3m-twist-n-fill-dispensing-system-3m
# https://certified.greenseal.org/product/3m-black-stripper-pad-7200-3m
# https://certified.greenseal.org/product/3m-blue-cleaner-pad-5300-3m
# https://certified.greenseal.org/product/3m-general-purpose-cleaner-concentrate-8a-3m-flow-control-system-3m
# ...

# %%
try:
    clk=driver.find_element(By.CSS_SELECTOR,"#index-table > div > div:nth-child(4) > div > a:nth-child(3) > img")
    driver.execute_script("arguments[0].click();", clk)
    time.sleep(5)
except:
    back()

# %%
import re
x=driver.find_element(By.CSS_SELECTOR,"#index-table > div > div:nth-child(4) > div > a:nth-child(2)").text
y=x.split("of")
for i in range(len(y)):
    y=(int(i))
y
# Out:
# 1

# %%
print(y)
# Out:
# ['Page 1 ', ' 1']

# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\User\OneDrive\Desktop\Data_acq\green_seal\companylink.xlsx')
for i in range(len(df)):
    URL=df.WebLink[i]
# Out:
# https://certified.greenseal.org/company/3m
# https://certified.greenseal.org/company/abc-compounding
# https://certified.greenseal.org/company/abco-cleaning-products
# https://certified.greenseal.org/company/accor-live-limitless
# https://certified.greenseal.org/company/ace-janitorial
# https://certified.greenseal.org/company/acme-paper-supply
# https://certified.greenseal.org/company/afflink-strategic-brands
# https://certified.greenseal.org/company/airlie
# https://certified.greenseal.org/company/airlite-am-technology
# https://certified.greenseal.org/company/al-bahar-industries
# https://certified.greenseal.org/company/alco-soap-supply
# https://certified.greenseal.org/company/alkavie-solutions
# https://certified.greenseal.org/company/almadion-international-gen-trading-llc
# https://certified.greenseal.org/company/american-cleaning-solutions
# https://certified.greenseal.org/company/american-formula
# https://certified.greenseal.org/company/american-hotel-register-co
# ...

# %%
Dic = {}
# from selenium import webdriver
gc= pd.DataFrame(data=Dic,index=[0],columns=['Name','Certified','Company','Brand','Iteam_Information','Website'])
                                  
      
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
df = pd.read_excel (r'C:/Users/User/OneDrive/Desktop/Data_acq/green_seal/Product_link.xlsx')
i=0
for i in range(len(df)):
    URL=df.Product_Link[i+1201]

    driver.get(URL)
    time.sleep(2)
    
    try:
        name=driver.find_element(By.CSS_SELECTOR,"#app > main > div > div:nth-child(3) > div > p:nth-child(1)")
        certified=driver.find_element(By.CSS_SELECTOR,"#app > main > div > div:nth-child(3) > div > div > div > div:nth-child(3)")
        cer=certified.text.split(":")
        company=driver.find_element(By.CSS_SELECTOR,"#app > main > div > div:nth-child(3) > div > div > div > div:nth-child(4) > a")
        brand=driver.find_element(By.CSS_SELECTOR,"#app > main > div > div:nth-child(3) > div > div > div > div:nth-child(5)")
        brand=brand.text.split(":")
        iteam_info=driver.find_element(By.CSS_SELECTOR,"#app > main > div > div:nth-child(3) > div > div > div > div:nth-child(6)")
        iteam=iteam_info.text.split(":")
        web=driver.find_element(By.CSS_SELECTOR,"#app > main > div > div:nth-child(3) > div > div > div > div:nth-child(7) > a")
        web=web.get_attribute('href')
        Dic={'Name':name.text,
        'Certified':cer[1],'Company':company.text,'Brand':brand[1],'Iteam_Information':iteam[1],'Website':web}
        gc = gc.append(Dic, ignore_index=True)
        print(gc)
    except:
        continue
# Out:
# <ipython-input-105-1fb14ed301e8>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
#                 Name Certified   Company   Brand Iteam_Information  \
# 0                NaN       NaN       NaN     NaN               NaN
# 1  Hypro Concentrate      2012  Pro Chem   Hypro            262307
#
#                                              Website
# 0                                                NaN
# 1  https://greenseal.org/standards/gs-37-cleaning...
#                                  Name Certified   Company             Brand  \
# 0                                 NaN       NaN       NaN               NaN
# 1                   Hypro Concentrate      2012  Pro Chem             Hypro
# 2  Pro-Link Aspire Bath Tissue, 2 Ply      2015  Pro-Link   Pro-Link Aspire
#
#   Iteam_Information                                            Website
# ...

# %%
print(gc)
# Out:
#                                                Name Certified  \
# 0                                               NaN       NaN
# 1                                 Hypro Concentrate      2012
# 2                Pro-Link Aspire Bath Tissue, 2 Ply      2015
# 3               Pro-Link Aspire Natural Roll Towels      2021
# 4                 Pro-Link Aspire White Roll Towels      2015
# ..                                              ...       ...
# 263                Ultra Super Heavy Duty Degreaser      2017
# 264                                     Ultra White      2018
# 265                           Ultra White Home Plus      2019
# 266                     Clea Blue Foaming Hand Wash      2009
# 267  Gleaming Green All Purpose Cleaner Concentrate      2010
#
#                  Company             Brand  \
# 0                    NaN               NaN
# 1               Pro Chem             Hypro
# 2               Pro-Link   Pro-Link Aspire
# ...

# %%
gc.to_excel(r'C:/Users/User/OneDrive/Desktop/Data_acq/Exported_File/Company_File/')

# %%
URL
# Out:
# 'https://certified.greenseal.org/facility/university-of-maryland-facilities-management'

# %%
i+1201
# Out:
# 1540

# %%
import openpyxl

workbook = openpyxl.load_workbook(r'C:/Users/User/OneDrive/Desktop/Data_acq/green_seal/Productinfo.xlsx')
writer = pd.ExcelWriter('C:/Users/User/OneDrive/Desktop/Data_acq/green_seal/Productinfo.xlsx', engine='openpyxl')
writer.book = workbook
writer.sheets = dict((ws.title, ws) for ws in workbook.worksheets)
data_df.to_excel(writer, 'Productinfo.xlsx')
writer.save()
writer.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-111-66745924c9cb> in <module>
#       2
#       3 workbook = openpyxl.load_workbook(r'C:/Users/User/OneDrive/Desktop/Data_acq/green_seal/Productinfo.xlsx')
# ----> 4 writer = pd.ExcelWriter('C:/Users/User/OneDrive/Desktop/Data_acq/green_seal/Productinfo.xlsx', engine='openpyxl')
#       5 writer.book = workbook
#       6 writer.sheets = dict((ws.title, ws) for ws in workbook.worksheets)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, path, engine, mode, storage_options, **engine_kwargs)
#      28         from openpyxl.workbook import Workbook
#      29
# ---> 30         super().__init__(
#      31             path, mode=mode, storage_options=storage_options, **engine_kwargs
#      32         )
#
# ...

# %%
df = pd.read_excel (r'C:/Users/User/OneDrive/Desktop/Data_acq/green_seal/Planetmark.xlsx')

# %%
df.Website[10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-f69cbd80bfcd> in <module>
# ----> 1 df.Website[10]
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Website'
