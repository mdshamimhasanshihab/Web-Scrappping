# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
driver.get("https://parksmart.gbci.org/projects")
# Out:
# <ipython-input-41-5a5d0c75367d>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

# %%
Dic = {}
# from selenium import webdriver
gc= pd.DataFrame(data=Dic,index=[0],columns=['company','Location'])

# %%
import os
import requests
x=driver.find_elements_by_class_name("field-content")
for i in range(len(x)):
    
    company=x[i*3+2].text
    
#     link=x[i*3+1].find_element_by_tag_name("a")
#     URL=(link.get_attribute("href"))
#     time.sleep(4)
    
#     driver.get(URL)
#     time.sleep(4)
#     z=driver.find_element_by_css_selector("#node-8575 > div > div.field.field-name-body.field-type-text-with-summary.field-label-above > div.field-items > div > p:nth-child(6) > a")
#     pdfURL=(z.get_attribute("href"))

#     output_dir='.\Outputs'

#     response=requests.get(pdfURL)

#     if response.status_code==200:
#         file_path=os.path.join(output_dir,os.path.basename(pdfURL))

#         with open(file_path,'wb') as f:
#             f.write(response.content)
            
            
#     print(company)
    location=company=x[i*3+2].text
    Dic={'company':company,'Location':location}
    gc = gc.append(Dic, ignore_index=True)
    print(gc)
# #     print(location)
#     if i>=(len(x)/3)-1:
#         break
# Out:
# <ipython-input-43-0db802d1af7a>:3: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   x=driver.find_elements_by_class_name("field-content")
#            company         Location
# 0              NaN              NaN
# 1  Toronto, Canada  Toronto, Canada
#                    company                 Location
# 0                      NaN                      NaN
# 1          Toronto, Canada          Toronto, Canada
# 2  Tysons Corner, Virginia  Tysons Corner, Virginia
#                    company                 Location
# 0                      NaN                      NaN
# 1          Toronto, Canada          Toronto, Canada
# 2  Tysons Corner, Virginia  Tysons Corner, Virginia
# 3  Bowling Green, Kentucky  Bowling Green, Kentucky
#                    company                 Location
# 0                      NaN                      NaN
# 1          Toronto, Canada          Toronto, Canada
# ...

# %%
gc.to_excel(r'C:/Users/User/OneDrive/Desktop/Data_acq/green_seal/Parksmart_1.7.22.xlsx')

# %%
driver.get("https://parksmart.gbci.org/yorkdale-shopping-centre-%E2%80%93-parkades-e-and-g")
z=driver.find_element_by_css_selector("#node-8575 > div > div.field.field-name-body.field-type-text-with-summary.field-label-above > div.field-items > div > p:nth-child(6) > a")
pdfURL=(z.get_attribute("href"))
import os
import requests
output_dir='.\Outputs'

response=requests.get(pdfURL)

if response.status_code==200:
    file_path=os.path.join(output_dir,os.path.basename(pdfURL))

    with open(file_path,'wb') as f:
        f.write(response.content)
# Out:
# <ipython-input-44-d2ba744be1f4>:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   z=driver.find_element_by_css_selector("#node-8575 > div > div.field.field-name-body.field-type-text-with-summary.field-label-above > div.field-items > div > p:nth-child(6) > a")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-d2ba744be1f4> in <module>
#       6 output_dir='.\Outputs'
#       7
# ----> 8 response=requests.get(pdfURL)
#       9
#      10 if response.status_code==200:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ...
