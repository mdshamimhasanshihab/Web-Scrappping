# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd

# %%
driver=webdriver.Chrome(executable_path="C:/Driver/cc/chromedriver.exe")
driver.get("https://www.google.com/webhp?hl=bn&sa=X&ved=0ahUKEwixto3mzc75AhXe5HMBHaFhAzkQPAgI")
driver.maximize_window()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7252\1517830716.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:/Driver/cc/chromedriver.exe")

# %%
search_text=pd.read_excel("test_in_vpn.xlsx").search_link
company_name=pd.read_excel("test_in_vpn.xlsx").Company_name

# %%
len(search_text)
# Out:
# 149

# %%
Dic = {}
# from selenium import webdriver
gc= pd.DataFrame(data=Dic,index=[0],columns=['Company_name','Wikipedia_link'])

# %%
import re
a_new_ven=re.compile('wikipedia')

# %%
search_bar=driver.find_element_by_css_selector("body > div.L3eUgb > div.o3j99.ikrT4e.om7nvf > form > div:nth-child(1) > div.A8SBwf > div.RNNXgb > div > div.a4bIc > input")
search_bar.send_keys(search_text[i])
search_bar.send_keys(Keys.ENTER)

# %%
first=driver.find_elements_by_class_name("yuRUbf")
links=[]
for li in range(0,3):
    link=first[li].find_element_by_tag_name("a").get_attribute("href")
    links.append(link)

print(links)

# %%
first=driver.find_elements_by_class_name("yuRUbf")
links=[]
for li in range(0,3):
    link=first[li].find_element_by_tag_name("a").get_attribute("href")
    print(link)
    linkk=link.split(".")
    for ll in linkk:
        if a_new_ven.match(ll):
            links.append(link)
            break
print(links)

# %%
for i in range(0,33):
    search_bar=driver.find_element_by_css_selector("body > div.L3eUgb > div.o3j99.ikrT4e.om7nvf > form > div:nth-child(1) > div.A8SBwf > div.RNNXgb > div > div.a4bIc > input")
    search_bar.send_keys(search_text[i])
    search_bar.send_keys(Keys.ENTER)
    time.sleep(2)
    try:
        first=first=driver.find_elements_by_class_name("yuRUbf")
        links=[]
        for li in range(0,3):
            link=first[li].find_element_by_tag_name("a").get_attribute("href")
#             print(link)
            linkk=link.split(".")
            for ll in linkk:
                if a_new_ven.match(ll):
                    links.append(link)
                    break
        Dic={'Company_name':company_name[i],'Wikipedia_link':links[0]}
        gc = gc.append(Dic, ignore_index=True)
        print(gc)
        driver.back()
        time.sleep(2)
        p=0
    except:
        p=p+1
    
        Dic={'Company_name':company_name[i],'Wikipedia_link':"N/A"}
        gc = gc.append(Dic, ignore_index=True)
        driver.back()
        time.sleep(2)
# Out:
# <ipython-input-17-49990f0fbeda>:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   search_bar=driver.find_element_by_css_selector("body > div.L3eUgb > div.o3j99.ikrT4e.om7nvf > form > div:nth-child(1) > div.A8SBwf > div.RNNXgb > div > div.a4bIc > input")
# <ipython-input-17-49990f0fbeda>:7: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   first=first=driver.find_elements_by_class_name("yuRUbf")
# <ipython-input-17-49990f0fbeda>:10: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   link=first[li].find_element_by_tag_name("a").get_attribute("href")
#                             Company_name  \
# 0                                    NaN
# 1                                  EDION
# 2    EIRCOM GROUP DEAD - DEAD - 18/08/06
# ...

# %%
gc.to_excel("after_vpn.xlsx")

# %%
for i in range(0,len(search_text)):
    search_bar=driver.find_element_by_css_selector("body > div.L3eUgb > div.o3j99.ikrT4e.om7nvf > form > div:nth-child(1) > div.A8SBwf > div.RNNXgb > div > div.a4bIc > input")
    search_bar.send_keys(search_text[i])
    search_bar.send_keys(Keys.ENTER)
    time.sleep(2)
    try:
        first=first=driver.find_element_by_class_name("yuRUbf")
        link=first.find_element_by_tag_name("a").get_attribute("href")
        Dic={'Company_name':company_name[i],'Wikipedia_link':link}
        gc = gc.append(Dic, ignore_index=True)
        print(gc)
        driver.back()
        time.sleep(2)
        p=0
    except:
        p=p+1
    
        Dic={'Company_name':company_name[i],'Wikipedia_link':"N/A"}
        gc = gc.append(Dic, ignore_index=True)
        driver.back()
        time.sleep(2)
# Out:
# <ipython-input-12-073572b8b2ed>:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   search_bar=driver.find_element_by_css_selector("body > div.L3eUgb > div.o3j99.ikrT4e.om7nvf > form > div:nth-child(1) > div.A8SBwf > div.RNNXgb > div > div.a4bIc > input")
# <ipython-input-12-073572b8b2ed>:7: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   first=first=driver.find_element_by_class_name("yuRUbf")
# <ipython-input-12-073572b8b2ed>:8: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   link=first.find_element_by_tag_name("a").get_attribute("href")
#   Company_name                                   Wikipedia_link
# 0          NaN                                              NaN
# 1        EDION  https://en.wikipedia.org/wiki/Horizon_Zero_Dawn
# ...

# %%
first=driver.find_element_by_class_name("yuRUbf").find_element_by_tag_name("a").get_attribute("href")

# %%
print(first)

# %%
cp=driver.find_element_by_class_name("")

# %%
name=driver.find_element_by_css_selector("#firstHeading").text
print(name)

# %%
try:
    table=driver.find_element_by_css_selector("#mw-content-text > div.mw-parser-output > table.infobox.vcard > tbody")
except:
    table=driver.find_element_by_css_selector("#mw-content-text > div.mw-parser-output > table > tbody")
    
tr=table.find_elements_by_tag_name("tr")

# %%
company=pd.read_excel("after_vpn.xlsx").Company_name
wiki_link=pd.read_excel("after_vpn.xlsx").Wikipedia_link

# %%
Dic = {}
# from selenium import webdriver
gc= pd.DataFrame(data=Dic,index=[0],columns=['Company_name','Wikipedia_link',"wiki_name","info_box"])

# %%
for z in range(0,len(wiki_link)):
    try:
        driver.get(wiki_link[z])
    except:
        Dic={'Company_name':company[z],'Wikipedia_link':wiki_link[z],"wiki_name":name,"info_box":"N/A"}
        gc = gc.append(Dic, ignore_index=True)
        continue
#     time.sleep(1)
    name=driver.find_element_by_css_selector("#firstHeading").text
    try:
        tabl=driver.find_elements_by_tag_name("table")
        table=tabl[0]
        if table.get_attribute("class")=="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove":
            table=tabl[1]
        tr=table.find_elements_by_tag_name("tr")
        if len(tr)<7:
            Dic={'Company_name':company[z],'Wikipedia_link':wiki_link[z],"wiki_name":name,"info_box":"N/A"}
            gc = gc.append(Dic, ignore_index=True)
            continue
        if table.get_attribute("class")=="wikitable":
            Dic={'Company_name':company[z],'Wikipedia_link':wiki_link[z],"wiki_name":name,"info_box":"N/A"}
            gc = gc.append(Dic, ignore_index=True)
            continue
#         except:
#             table=driver.find_element_by_css_selector("#mw-content-text > div.mw-parser-output > table > tbody")
#             tr=table.find_elements_by_tag_name("tr")
            
    except:
        Dic={'Company_name':company[z],'Wikipedia_link':wiki_link[z],"wiki_name":name,"info_box":"N/A"}
        gc = gc.append(Dic, ignore_index=True)
        continue
        
        
    

    lst=[]
    for i in range(1,len(tr)):
        try:
            hd=tr[i].find_element_by_tag_name("th").text
            td=tr[i].find_element_by_tag_name("td").text

            row= hd+" : "+td

            lst.append(row)
    #         print(row)
        except:
            continue
    Dic={'Company_name':company[z],'Wikipedia_link':wiki_link[z],"wiki_name":name,"info_box":lst}
    gc = gc.append(Dic, ignore_index=True)
#     time.sleep(1)

    print(gc)
# Out:
# <ipython-input-28-c421471d36b2>:9: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   name=driver.find_element_by_css_selector("#firstHeading").text
# <ipython-input-28-c421471d36b2>:11: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   tabl=driver.find_elements_by_tag_name("table")
# <ipython-input-28-c421471d36b2>:15: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   tr=table.find_elements_by_tag_name("tr")
# <ipython-input-28-c421471d36b2>:39: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   hd=tr[i].find_element_by_tag_name("th").text
# ...

# %%
box=driver.find_element_by_css_selector("#mw-content-text > div.mw-parser-output > table")

# %%
for i in box:
    print(i.text)

# %%
gc.to_excel("after_vpn_info.xlsx")

# %%
import pandas as pd
company=pd.read_excel("NA_file.xlsx").Company_name
wiki_link=pd.read_excel("NA_file.xlsx").Wikipedia_link

# %%
driver.get(wiki_link[21])

# %%
table=driver.find_element_by_tag_name("table")
# table=driver.find_element_by_css_selector("#mw-content-text > div.mw-parser-output > table")
tr=table.find_elements_by_tag_name("tr")
# infobox_v2 noarchive

# %%
# print(table.get_attribute("class"))
if table.get_attribute("class")=="wikitable":
    print("yes")
for i in tr:
    print(i.text)
#     for i in tr:
#         print("yes")
#     print(i.text)
    
len(tr)
