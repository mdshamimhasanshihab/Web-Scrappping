# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.support.ui import Select

# %%
driver=webdriver.Chrome(executable_path="C:/Driver/cc/chromedriver.exe")
driver.get("https://www.naturland.de/de/naturland/wo-wir-sind/betriebsportraets.html")
driver.maximize_window()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11060\3374770583.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:/Driver/cc/chromedriver.exe")

# %%
tbl=driver.find_element(By.CSS_SELECTOR,"body > div.dj-offcanvas-wrapper > div > div > div > div.uk-section-default.uk-section.uk-section-small.uk-padding-remove-top.uk-padding-remove-bottom > div > div > div.uk-width-3-4\@m.uk-first-column > div.uk-margin-medium.uk-text-left > div")

# %%
Dic = {}
gc= pd.DataFrame(data=Dic,index=[0],columns=["Organization",'description','url'])

# %%
tbl=driver.find_element(By.CSS_SELECTOR,"body > div.dj-offcanvas-wrapper > div > div > div > div.uk-section-default.uk-section.uk-section-small.uk-padding-remove-top.uk-padding-remove-bottom > div > div > div.uk-width-3-4\@m.uk-first-column > div.uk-margin-medium.uk-text-left > div")
for a in range(len(name)):
    name=tbl.find_elements(By.TAG_NAME,"h2")
    des=tbl.find_elements(By.TAG_NAME,"p")
    link=tbl.find_elements(By.TAG_NAME,"a")
    Dic={"Organization":name[a].text,'url':link[a].get_attribute("href"),'description':des[a].text}
    gc = gc.append(Dic, ignore_index=True)
    print(gc)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11060\1944169399.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc = gc.append(Dic, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_11060\1944169399.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc = gc.append(Dic, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_11060\1944169399.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc = gc.append(Dic, ignore_index=True)
#     Organization                                        description  \
# 0            NaN                                                NaN
# 1  VINEYARD SECK  Vineyard tours, tastings, holidays and verniss...
#
# ...

# %%
name=tbl.find_elements(By.TAG_NAME,"h2")
print(name)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="62f02b88200432a9c8c994366433b941", element="59df2e25-a875-433b-8b22-66b474f9ef6d")>, <selenium.webdriver.remote.webelement.WebElement (session="62f02b88200432a9c8c994366433b941", element="1498a08b-7520-4454-909c-95970b34fb72")>, <selenium.webdriver.remote.webelement.WebElement (session="62f02b88200432a9c8c994366433b941", element="6394ecaf-99ed-431b-b767-66a8d87a7c89")>, <selenium.webdriver.remote.webelement.WebElement (session="62f02b88200432a9c8c994366433b941", element="1cc9aa75-99d5-4bbb-83ae-a165b6b4d118")>, <selenium.webdriver.remote.webelement.WebElement (session="62f02b88200432a9c8c994366433b941", element="f0ce07c0-7e0b-4c38-b22a-e267d97903fe")>, <selenium.webdriver.remote.webelement.WebElement (session="62f02b88200432a9c8c994366433b941", element="9685ef50-6128-44be-aacf-947ec0a0a004")>, <selenium.webdriver.remote.webelement.WebElement (session="62f02b88200432a9c8c994366433b941", element="2f22310d-5275-4648-8405-473428
# ...

# %%
for a in range(1,len(gc)):
    driver.get(gc.url[a])

# %%
Dic1 = {}
gc1= pd.DataFrame(data=Dic1,index=[0],columns=["Organization",'description','url','address','region','phone','fax','email'])

# %%
for x in range(1,len(link)):
    driver.get(gc.url[x])
    address=driver.find_elements(By.CLASS_NAME,"el-item")[0].text
    region=driver.find_elements(By.CLASS_NAME,"el-item")[1].text
    phone=driver.find_elements(By.CLASS_NAME,"el-item")[2].text
    fax=driver.find_elements(By.CLASS_NAME,"el-item")[3].text
    email=driver.find_elements(By.CLASS_NAME,"el-item")[4].text
    Dic1={"Organization":gc.Organization[x],'description':gc.description[x],'url':gc.url[x],'address':address,'region':region,'phone':phone,'fax':fax,'email':email}
    gc1 = gc1.append(Dic1, ignore_index=True) 
    time.sleep(1)
    print(gc1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11060\2007542516.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc1 = gc1.append(Dic1, ignore_index=True)
#     Organization                                        description  \
# 0            NaN                                                NaN
# 1  VINEYARD SECK  Vineyard tours, tastings, holidays and verniss...
#
#                                                  url  \
# 0                                                NaN
# 1  https://www.naturland.de/de/naturland/wo-wir-s...
#
#                     address            region            phone  \
# 0                       NaN               NaN              NaN
# 1  Weinolsheimer Strasse 12  55278 Dolgesheim  +49 (0)6733 324
#
#                 fax                 email
# 0               NaN                   NaN
# 1  +49 (0)6733 8616  info@weingut-seck.de
# ...

# %%
print(len(link))
# Out:
# 19

# %%
gc.to_excel("Nature land_15_09_22_Kazi.xlsx")

# %%
address=driver.find_elements(By.CLASS_NAME,"el-item")[0].text
region=driver.find_elements(By.CLASS_NAME,"el-item")[1].text
phone=driver.find_elements(By.CLASS_NAME,"el-item")[2].text
fax=driver.find_elements(By.CLASS_NAME,"el-item")[3].text
email=driver.find_elements(By.CLASS_NAME,"el-item")[4].text
print(address)
print(region)
print(phone)
print(email)
# Out:
# Kirchender Dorfweg 26
# 58313 Herdecke
# +49 (0)2330 9744-54
# hof-niermann@t-online.de
