# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import re

# %%
for z in range(100):
    block=driver.find_elements_by_class_name("wpgmp_locations")
    for i in range(len(block)):
        company=block[i].find_element_by_class_name("wpgmp_location_title").text
    #   pass print(company)
        producer=block[i].find_elements_by_tag_name("p")[1].text
    #     print(address)
        address=block[i].find_elements_by_tag_name("p")[2].text
    #     print(address)
        phone=block[i].find_elements_by_tag_name("p")[4].text
    #     print(phone)
        email=block[i].find_elements_by_tag_name("p")[5].text
    #     print(email)
        web=block[i].find_elements_by_tag_name("p")[6].text
    #     print(web)
        product_type=block[i].find_elements_by_tag_name("p")[7].text.split(":")[1]
#         print(product_type)
        Dic={'Company':company,'Producer':producer,'address':address,'phone':phone,'email':email,'web':web,'product_type':product_type}
        gc1 = gc1.append(Dic, ignore_index=True)
        print(gc1)
    clk=driver.find_element(By.CLASS_NAME,"next")
    driver.execute_script("arguments[0].click();", clk)
# Out:
# <ipython-input-9-7ca708d2b240>:2: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   block=driver.find_elements_by_class_name("wpgmp_locations")
# <ipython-input-9-7ca708d2b240>:4: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   company=block[i].find_element_by_class_name("wpgmp_location_title").text
# <ipython-input-9-7ca708d2b240>:6: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   producer=block[i].find_elements_by_tag_name("p")[1].text
# <ipython-input-9-7ca708d2b240>:8: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   address=block[i].find_elements_by_tag_name("p")[2].text
# ...

# %%
gc1.to_excel(r"C:\Users\User\OneDrive\Desktop\Data_acq\Exported_File\Company_File\American grassfed_18_07_22.xlsx")
