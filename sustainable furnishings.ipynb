# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import re

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
driver.get("https://www.ewg.org/ewgverified/products.php?models=cosmetic%2Cdiaper&search=&minority_owned=&brand=&category=&sort=newest&type=")
# Out:
# <ipython-input-3-81ca11431092>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.maximize_window()

# %%
Dic = {}
# from selenium import webdriver
gc= pd.DataFrame(data=Dic,index=[0],columns=['company','Standard','web','address','phone','Sustainable materials','Recycling and Reclamation',
                                            'Return and Reuse','Chain of Custody','Decrease use of Toxic Chemicals','Low Environmental Impact Textiles',
                                            'Life Cycle Analysis','Local Sourcing','Third Party Certifications','Sharing the Wealth','Social Responsibility Code','Supplier Responsibility',
                                            'Health and Safety Code Compliance','We Pay Living Wages','We Sponsor Sustainability Events','We Inspect','Save Paper and Other Office Resources','We Use Energy Specialists',
                                            'Updated Inefficient Equipment','Energy Efficient Lighting','Verified Sustainability Claims','Committed to Training'])

# %%
# for k in range(15):


rows=driver.find_elements_by_tag_name("tr")
for i in range(len(rows)):
    tick=[]
    if i==0:
        continue
    elements=rows[i].find_elements_by_tag_name("td")
    web=rows[i].find_element_by_class_name("member_url")
#     page=rows[i].find_element_by_class_name("memberlist_type")

    websb=web.get_attribute("href")
#     print(page.get_attribute("href"))

    for element in range(len(elements)):
        try:
            company_name=elements[element].find_element_by_tag_name("p").text.split("\n")[0]
            standard=elements[element].find_element_by_tag_name("p").text.split("\n")[1]

            page=elements[element].find_element_by_tag_name("a")
            URL=page.get_attribute("href")


        except:
            continue
#     print(company_name)
#     print(standard)
    print(URL)
    

#         Dic={'company':company_name,'Standard':standard,'web':websb}
#         gc = gc.append(Dic, ignore_index=True)
    driver.get(URL)
    time.sleep(4)
#     if i==4:
#         break




    addrs = driver.find_element_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing > span > div > div.c1 > div.address')
    addrs = addrs.text
    code=driver.find_element_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing > span > div > div.c1 > div.phone')
    phone=code.text
    gg = driver.find_elements_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing-3 > span > div > div.bplisting')
    ll = len(gg)
    for p in range(ll):
        gk = driver.find_elements_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing-3 > span > div > div.bplisting > div:nth-child(2)')
        gk = gk[p].get_attribute('class')
        pattern = re.compile(r'(YES|NO)')
        matches = pattern.finditer(gk)
        for match in matches:
            gk = match.group()
        tick.append(gk)


    Dic={'company':company_name,'Standard':standard,'web':websb,'address':addrs,'phone':phone,'Sustainable materials':tick[0],'Recycling and Reclamation':tick[1],
                                            'Return and Reuse':tick[2],'Chain of Custody':tick[3],'Decrease use of Toxic Chemicals':tick[4],'Low Environmental Impact Textiles':tick[5],
                                            'Life Cycle Analysis':tick[6],'Local Sourcing':tick[7],'Third Party Certifications':tick[8],'Sharing the Wealth':tick[9],'Social Responsibility Code':tick[10],'Supplier Responsibility':tick[11],
                                            'Health and Safety Code Compliance':tick[12],'We Pay Living Wages':tick[13],'We Sponsor Sustainability Events':tick[14],'We Inspect':tick[15],'Save Paper and Other Office Resources':tick[16],'We Use Energy Specialists':tick[17],
                                            'Updated Inefficient Equipment':tick[18],'Energy Efficient Lighting':tick[19],'Verified Sustainability Claims':tick[20],'Committed to Training':tick[21]}
    gc = gc.append(Dic, ignore_index=True)
            # Switch to the Previous window
    print(gc)
    driver.back()
    time.sleep(4)


    #     hrf=rows[i].find_elements_by_class_name("member_url")
    #     print(hrf.)
    #     for element in range(len(elements)):
    #         print(element)
#             print(gc)
#     clk = driver.find_element_by_css_selector("#content > div > div.view.view-vw-manufacturers.view-id-vw_manufacturers.view-display-id-page_8.view-dom-id-96c31002694f186ef1d3f579a0c92c8e > div.item-list > ul > li.pager-next > a")
#     x=clk.get_attribute("href")
#     driver.get(x)
#     time.sleep(5)
# Out:
# <ipython-input-263-78c89ed8b3cd>:4: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   rows=driver.find_elements_by_tag_name("tr")
# <ipython-input-263-78c89ed8b3cd>:9: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   elements=rows[i].find_elements_by_tag_name("td")
# <ipython-input-263-78c89ed8b3cd>:10: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   web=rows[i].find_element_by_class_name("member_url")
# <ipython-input-263-78c89ed8b3cd>:18: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   company_name=elements[element].find_element_by_tag_name("p").text.split("\n")[0]
# ...

# %%
# from selenium import webdriver
# import time
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.by import By
# import pandas as pd
# import re
# driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
# driver.get("https://sustainablefurnishings.org/memberlist")
# clk = driver.find_element_by_css_selector("#content > div > div.view.view-vw-manufacturers.view-id-vw_manufacturers.view-display-id-page_8.view-dom-id-96c31002694f186ef1d3f579a0c92c8e > div.item-list > ul > li.pager-next > a")
# # x=clk.get_attribute("href")
# driver.get(x)
print(i)
# driver.execute_script("arguments[0].click();", clk)
# Out:
# 6

# %%
gc.to_excel(r'C:\Users\User\OneDrive\Desktop\Data_acq\Exported_File\Company_File\sustainable furnishings_4.7.22.xlsx')

# %%
    driver.get("https://sustainablefurnishings.org/company?id=35366")
    time.sleep(4)
    addrs = driver.find_element_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing > span > div > div.c1 > div.address')
    addrs = addrs.text
    print(addrs)
    code=driver.find_element_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing > span > div > div.c1 > div.phone')
    phone=code.text
    gg = driver.find_elements_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing-3 > span > div > div.bplisting')
    ll = len(gg)
    for p in range(ll):
        gk = driver.find_elements_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing-3 > span > div > div.bplisting > div:nth-child(2)')
        gk = gk[p].get_attribute('class')
        pattern = re.compile(r'(YES|NO)')
        matches = pattern.finditer(gk)
        for match in matches:
            gk = match.group()
        tick.append(gk)
    
    
    Dic={'company':company_name,'Standard':standard,'web':websb,'address':addrs,'phone':phone,'Sustainable materials':tick[0],'Recycling and Reclamation':tick[1],
                                            'Return and Reuse':tick[2],'Chain of Custody':tick[3],'Decrease use of Toxic Chemicals':tick[4],'Low Environmental Impact Textiles':tick[5],
                                            'Life Cycle Analysis':tick[6],'Local Sourcing':tick[7],'Third Party Certifications':tick[8],'Sharing the Wealth','Social Responsibility Code':tick[9],'Supplier Responsibility':tick[10],
                                            'Health and Safety Code Compliance':tick[11],'We Pay Living Wages':tick[12],'We Sponsor Sustainability Events':tick[13],'We Inspect':tick[14],'Save Paper and Other Office Resources':tick[15],'We Use Energy Specialists':tick[16],
                                            'Updated Inefficient Equipment':tick[17],'Energy Efficient Lighting':tick[18],'Verified Sustainability Claims':tick[19],'Committed to Training':tick[20]}
    gc = gc.append(Dic, ignore_index=True)
            # Switch to the Previous window
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
    
#     print('Sustainable Materials :-',tick[0])
#     print('Recycling and Reclamation :-',tick[1])
#     print('Return and Reuse :-',tick[2])
# Out:
# 1610 Redi Rd
# Cumming Georgia
# United States
# 678-267-2023
# <ipython-input-183-8144e6ffbefd>:3: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   addrs = driver.find_element_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing > span > div > div.c1 > div.address')
# <ipython-input-183-8144e6ffbefd>:6: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   code=driver.find_element_by_css_selector('#content > div > div > div.view-content > div > div.views-field.views-field-nothing > span > div > div.c1 > div.phone')

# %%
rows=driver.find_elements_by_tag_name("tr")

for i in range(len(rows)):
# #     if i==0:
#         continue
    elements=rows[i].find_elements_by_tag_name("td")
    hrf=rows[i].find_elements_by_class_name("member_url")

    for element in range(len(elements)):
        website=hrf[element].text
#         company_name=elements[element].find_element_by_tag_name("p").text.split("\n")[0]
#         standard=elements[element].find_element_by_tag_name("p").text.split("\n")[1]
#         print(standard)
# Out:
# <ipython-input-142-a402cb9f7ff1>:1: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   rows=driver.find_elements_by_tag_name("tr")
# <ipython-input-142-a402cb9f7ff1>:6: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   elements=rows[i].find_elements_by_tag_name("td")
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-142-a402cb9f7ff1> in <module>
#       8
#       9     for element in range(len(elements)):
# ---> 10         website=hrf[element].text
#      11 #         company_name=elements[element].find_element_by_tag_name("p").text.split("\n")[0]
#      12 #         standard=elements[element].find_element_by_tag_name("p").text.split("\n")[1]
#
# IndexError: list index out of range

# %%
page=driver.find_elements_by_tag_name("tr")
print(page)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0a86e57e3c0f0eaa1963b79b864615e8", element="b9702020-88d0-47ec-9221-08ab7b89d9c6")>, <selenium.webdriver.remote.webelement.WebElement (session="0a86e57e3c0f0eaa1963b79b864615e8", element="49b543b1-f1dd-48bf-98d3-3908dac6062e")>, <selenium.webdriver.remote.webelement.WebElement (session="0a86e57e3c0f0eaa1963b79b864615e8", element="7b3f2f46-2c4d-4eef-88ca-6ea0a7350675")>, <selenium.webdriver.remote.webelement.WebElement (session="0a86e57e3c0f0eaa1963b79b864615e8", element="66e9b5a9-b37b-48ec-963d-73951439ebd4")>, <selenium.webdriver.remote.webelement.WebElement (session="0a86e57e3c0f0eaa1963b79b864615e8", element="e66bf419-408e-450b-ac76-8124ff0750cb")>, <selenium.webdriver.remote.webelement.WebElement (session="0a86e57e3c0f0eaa1963b79b864615e8", element="edb122a6-7ab3-4195-a221-f46952c4efa1")>, <selenium.webdriver.remote.webelement.WebElement (session="0a86e57e3c0f0eaa1963b79b864615e8", element="187d5f35-5ba9-4fb8-9e60-0a4447
# ...
