# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import re

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
driver.get("https://www.sustainableagriculture.eco/our-members")
# Out:
# <ipython-input-105-a3b5390f295e>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.maximize_window()

# %%
body=driver.find_elements_by_tag_name("a")
for i in range(len(body)):
    URL=body[i].get_attribute("href")
    print(URL)
# Out:
# <ipython-input-31-8426ccbcfd4b>:1: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   body=driver.find_elements_by_tag_name("a")
# https://www.sustainableagriculture.eco/
# https://www.sustainableagriculture.eco/
# https://www.sustainableagriculture.eco/blog
# https://www.sustainableagriculture.eco/our-vision
# https://www.sustainableagriculture.eco/our-team-2
# https://www.sustainableagriculture.eco/our-mission
# https://www.sustainableagriculture.eco/accountability
# https://www.sustainableagriculture.eco/get-in-touch
# https://www.sustainableagriculture.eco/our-members
# https://www.sustainableagriculture.eco/governance
# https://www.sustainableagriculture.eco/clients-and-donors
# https://www.sustainableagriculture.eco/partners
# https://www.sustainableagriculture.eco/our-priorities
# https://www.sustainableagriculture.eco/signature-programs
# https://www.sustainableagriculture.eco/projects
# ...

# %%
member=body.find_elements_by_class_name("row sqs-row")
print(member)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-cca0390c5aca> in <module>
# ----> 1 member=body.find_elements_by_class_name("row sqs-row")
#       2 print(member)
#
# AttributeError: 'list' object has no attribute 'find_elements_by_class_name'

# %%
df=pd.read_excel("wild.xlsx")

# %%
for i in range(len(df.Link)):
    print(df.Link[i*2])
    driver.get(df.Link[i*2])
    
    if i>17:
        break
# Out:
# https://www.sustainableagriculture.eco/ask
# https://www.sustainableagriculture.eco/cabi
# https://www.sustainableagriculture.eco/cad
# https://www.sustainableagriculture.eco/profilecefca
# https://www.sustainableagriculture.eco/profile-fiit
# https://www.sustainableagriculture.eco/fundacion-global-nature
# https://www.sustainableagriculture.eco/profile-fundacion-natura
# https://www.sustainableagriculture.eco/profile-icade
# https://www.sustainableagriculture.eco/profileicade
# https://www.sustainableagriculture.eco/profile-nature-kenya
# https://www.sustainableagriculture.eco/pelum-uganda
# https://www.sustainableagriculture.eco/profile-nature-kenya-1
# https://www.sustainableagriculture.eco/profilepronatura
# https://www.sustainableagriculture.eco/raaa
# https://www.sustainableagriculture.eco/profile-rainforest-alliance
# https://www.sustainableagriculture.eco/reeds-pakistan
# https://www.sustainableagriculture.eco/profile-rspb
# ...

# %%
driver.get("https://www.sustainableagriculture.eco/cabi")

# %%
C_name=driver.find_element_by_tag_name("h1").text
p=driver.find_elements_by_tag_name("div")
for i in p:
    print(i.text)
# Out:
# <ipython-input-119-0a00874a7231>:1: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   C_name=driver.find_element_by_tag_name("h1").text
# <ipython-input-119-0a00874a7231>:2: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   p=driver.find_elements_by_tag_name("div")
# HOME ABOUT US
# NETWORK
# OUR WORK
# TOOLS
# BLOG LANGUAGE
# Map Data
# Terms of Use
# ←Back
# CABI
# “By sharing knowledge and science, we tackle global issues like poverty, hunger, education, equality, sustainability, climate change and biodiversity.”
# CABI does this by helping farmers grow more and lose less of what they produce, combating threats to agriculture and the environment from pests and diseases, protecting natural habitats from invasive species, and improving access to scientific knowledge.
# Mission
# ...
