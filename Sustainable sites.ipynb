# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import re

# %%
df = pd.read_excel (r'C:/Users/User/OneDrive/Desktop/Data_acq/t.xlsx')

# %%
URL=df.web[0]
print(URL)
# Out:
# https://true.gbci.org/state-farm-arena

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
driver.get("https://www.sustainablesites.org/node/8478")
# Out:
# <ipython-input-37-f7bdc7947aa2>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

# %%
Dic2 = {}
# from selenium import webdriver
gc2= pd.DataFrame(data=Dic2,index=[0],columns=['project_name','location','project_size','project_type','Percent of Overall Diversion Achieved','Certification Level','Project_Owner','web'])

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

for i in range(len(df.web)):
    URL=df.web[i]
    driver.get(URL)
    time.sleep(5)
    div=driver.find_elements_by_class_name("field-items")
    try:
        Project_name=driver.find_element_by_tag_name("h1").text
    except:
        Project_name="N/A"
    try:    
        location=div[1].text
    except:
        location="N/A"
    try:
        
        c_level=div[2].text
    except:
        c_level="N/A"
    try:
        poda=div[3].text
    except:
        poda="N/A"
    try:
        f_size=div[4].text
    except:
        f_size="N/A"
    try:
        p_type=div[5].text
    except:
        p_type="N/A"
    try:
        p_owner=div[6].text
    except:
        p_owner="N/A"
    Dic2={'project_name':Project_name,'location':location,'project_size':f_size,'project_type':p_type,'Percent of Overall Diversion Achieved':poda,'Certification Level':c_level,'Project_Owner':p_owner,'web':URL}
    gc2 = gc2.append(Dic2, ignore_index=True)
    print(gc2)
    # web
# Dic2{'project_name','location','project_size','site_context','former_land_use','Terrestrial_Biome'}
# Out:
# <ipython-input-51-7b62f7ef40e5>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
# <ipython-input-51-7b62f7ef40e5>:7: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   div=driver.find_elements_by_class_name("field-items")
# <ipython-input-51-7b62f7ef40e5>:9: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   Project_name=driver.find_element_by_tag_name("h1").text
#        project_name          location     project_size  \
# 0               NaN               NaN              NaN
# 1  State Farm Arena  Atlanta, Georgia  680,000 sq. ft.
#
#              project_type Percent of Overall Diversion Achieved  \
# 0                     NaN                                   NaN
# ...

# %%
gc2.to_excel(r'C:/Users/User/OneDrive/Desktop/Data_acq/Exported_File/Company_File/GBCI-13.07.22.xlsx')

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

URL=df.web[i]
driver.get("https://true.gbci.org/state-farm-arena")
time.sleep(5)
try:
    Project_name=driver.find_element_by_tag_name("h1").text
except:
    Project_name="N/A"
try:    
    location=driver.find_element_by_css_selector("#node-15797 > div > div.field.field-name-field-location.field-type-text.field-label-inline.clearfix > div.field-items > div").text
except:
    location="N/A"
try:

    c_level=driver.find_element_by_css_selector("#node-15797 > div > div.field.field-name-field-certification-level.field-type-text.field-label-inline.clearfix > div.field-items > div").text
except:
    c_level="N/A"
try:
    poda=driver.find_element_by_css_selector("#node-15797 > div > div.field.field-name-field-percent-of-overall-diversi.field-type-text.field-label-inline.clearfix > div.field-items > div").text
except:
    poda="N/A"
try:
    f_size=driver.find_element_by_css_selector("#node-15797 > div > div.field.field-name-field-facility-size.field-type-text.field-label-inline.clearfix > div.field-items > div").text
except:
    f_size="N/A"
try:
    p_type=driver.find_element_by_css_selector("#node-15797 > div > div.field.field-name-field-type-of-operation.field-type-text.field-label-inline.clearfix > div.field-items > div").text
except:
    p_type="N/A"
try:
    p_owner=driver.find_element_by_css_selector("#node-15797 > div > div.field.field-name-field-project-owner.field-type-text.field-label-inline.clearfix > div.field-items > div").text
except:
    p_owner="N/A"
Dic2={'project_name':Project_name,'location':location,'project_size':f_size,'project_type':p_type,'Percent of Overall Diversion Achieved':poda,'Certification Level':c_level,'Project_Owner':p_owner,'web':URL}
gc2 = gc2.append(Dic2, ignore_index=True)
print(gc2)
# Out:
# <ipython-input-41-3cab4ac1a382>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
#                                         project_name location project_size  \
# 0                                                NaN      NaN          NaN
# 1                                   State Farm Arena      N/A          N/A
# 2        Best Buy - Regional Distribution Center 725      N/A          N/A
# 3  W.W. Grainger, Dallas Fort Worth Distribution ...      N/A          N/A
# 4              Milo's Tea Company, Oklahoma Facility      N/A          N/A
# 5                                Oxford Frozen Foods      N/A          N/A
# 6                                   State Farm Arena      N/A          N/A
#
#   project_type Percent of Overall Diversion Achieved Certification Level  \
# 0          NaN                                   NaN                 NaN
# ...

# %%
div=driver.find_elements_by_class_name("field-items")
print(div[5].text)
# Out:
# Sports & Entertainment
# <ipython-input-49-c4b14a2897a6>:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   div=driver.find_elements_by_class_name("field-items")
