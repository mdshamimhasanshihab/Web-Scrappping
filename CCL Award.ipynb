# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.support.ui import Select

# %%
driver=webdriver.Chrome(executable_path="C:/Driver/cc/chromedriver.exe")
driver.get("https://www.ccinnolab.org/CCLAwardees")
driver.maximize_window()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9956\3427914985.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:/Driver/cc/chromedriver.exe")

# %%
para=driver.find_element(By.CSS_SELECTOR,"#v-pills-2019")

# %%
award_type=para.find_elements(By.CLASS_NAME,"label_level")
for i in award_type:
    print(i.text)
len(award_type)
# Out:
# Level of Award - 3
# Level of Award - 2
# Level of Award - 1
# Level of Award - Champion (Carbon Neutral)
# Level of Award - 3 (40% Reduction)
# Level of Award - 2 (20% Reduction)
# Level of Award - 1 (5% Reduction)
# 7

# %%
Dic = {}
gc= pd.DataFrame(data=Dic,index=[0],columns=['award','award_type','year'])

# %%
ur=driver.find_element(By.CSS_SELECTOR,"#v-pills-tab")
url=ur.find_elements(By.TAG_NAME,"a")
for i in range(len(e)):
    time.sleep(2)
    url[i].click()
    class_name="#v-pills-"+f"{d[i]}"
    para=driver.find_element(By.CSS_SELECTOR,f"{class_name}")
    award_type=para.find_elements(By.CLASS_NAME,"label_level")
    of=para.find_elements(By.CLASS_NAME,"labellist")
    for a in range(len(award_type)):
        com=of[a].find_elements(By.TAG_NAME,"p")
        awarrd=award_type[a].text
        for b in com:
            company_name=b.text
            Dic={'award':company_name,'award_type':awarrd,'year':d[i]}
            gc = gc.append(Dic, ignore_index=True)
            print(gc)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9956\2415975432.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc = gc.append(Dic, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_9956\2415975432.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc = gc.append(Dic, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_9956\2415975432.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc = gc.append(Dic, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_9956\2415975432.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc = gc.append(Dic, ignore_index=True)
# ...

# %%
gc.to_excel("CCL Award_21_09_22_Kazi.xlsx")

# %%
for z in [2021,2020,2019,2018,2017,2016,2015,2014,2013]:
    class_name="#v-pills-"+f"{z}"
    print(class_name)
# Out:
# #v-pills-2021
# #v-pills-2020
# #v-pills-2019
# #v-pills-2018
# #v-pills-2017
# #v-pills-2016
# #v-pills-2015
# #v-pills-2014
# #v-pills-2013

# %%
ur=driver.find_element(By.CSS_SELECTOR,"#v-pills-tab")
url=ur.find_elements(By.TAG_NAME,"a")
for i in url:
    i.click()

# %%
d=[2021,2020,2019,2018,2017,2016,2015,2014,2013]
e=[2020,2020,2019,2018,2017,2016,2015,2014,2013]

# %%
for i in range(len(url)):
    li=url[i].click()
    print(li)
    driver.get(li)
# Out:
# None
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
#       2 li=url[i].click()
#       3 print(li)
# ----> 4 driver.get(li)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """
#     438     Loads a web page in the current browser session.
#     439     """
# --> 440     self.execute(Command.GET, {'url': url})
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
# ...

# %%
cl=driver.find_element(By.CSS_SELECTOR,"#v-pills-2018-tab").click()

# %%
css="#v-pills-"+f"{e[i]}"+"-tab"
