# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd

# %%
driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")
driver.get("https://www.waterwise.org.uk/supporters-and-affiliates/#wwsupporters")
# Out:
# <ipython-input-57-0f796d34624e>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\Driver\chromedriver_win32 (3)\chromedriver.exe")

# %%
from selenium.webdriver.common.by import By
links=driver.find_elements(By.TAG_NAME,"a")

# %%
i=0
for i in range(len(links)):
    print(links[i+160].get_attribute('href'))
    if i==29:
        break
# Out:
# https://www.anglianwater.co.uk/
# https://www.business-stream.co.uk/
# https://www.eswater.co.uk/
# http://www.deevalleywater.co.uk/
# https://naturalresources.wales/?lang=en
# http://www.niwater.com/
# http://www.nwl.co.uk/
# http://www.portsmouthwater.co.uk/
# http://www.scottishwater.co.uk/
# http://www.waterplc.com/
# http://www.stwater.co.uk/
# http://www.southernwater.co.uk/
# http://www.south-staffs-water.co.uk/
# http://www.southeastwater.co.uk/
# http://www.southwestwater.co.uk/
# http://www.thameswater.co.uk/
# https://www.unitedutilities.com/
# https://www.wave-utilities.co.uk/
# http://www.dwrcymru.com/
# http://www.wessexwater.co.uk/
# http://www.yorkshirewater.com/
# https://www.water.ie/
# https://www.methven.com/uk/home
# http://www.advizzo.com/
# http://www.arqiva.com/
# https://www.artesia-consulting.co.uk/
# https://babydam.com/product/babydam-family-of-ducks-bath/
# https://www.cenergist.com/
# http://www.groundbreaker.co.uk/
# https://skewb.co.uk/

# %%
x=driver.find_elements(By.CLASS_NAME,"elementor-widget-container")

# %%
for i in x:
    print(i.text)
    
#     print(x[i].text)
#     title=i.find_element_by_xpath(".//*[@id="content"]/div/div/div/div/section[8]/div/div/div/div/div/section[1]/div/div/div[1]/div/div/div[4]")
#     print(title)
# Out:
# 0208 164 1490
# info@waterwise.org.uk
# Sign Up to Our Newsletter
#
#
#
#
#
#
# Supporters and Affiliates
# We find Waterwise's partnership approach and its relentless drive for ambition right across the sector refreshing and effective. It manages to be both supportive and challenging to us as an individual business and also to government and regulators to drive the policy changes we need to deliver our ambitious Target 100 water efficiency programme. We particularly welcome Waterwise's engagement on water efficiency of the non usual suspects within water companies, for example Chief Customer Officers through its Leadership Group - and with water retailers to drive the water efficiency we need to see in businesses.
# Ian McAulay, Chief Executive, Southern Water
#
# Case for Support
# See the Case for Support Here
#
# Why be a Waterwise Supporter or Affiliate?
#
# ...

# %%
//*[@id="content"]/div/div/div/div/section[8]/div/div/div/div/div/section[1]/div/div/div[1]/div/div/div[4]

# %%
y=driver.find_elements(By.CLASS_NAME,"elementor-widget-container")
for i in range(len(y)):
    print(y[i].get_attribute('href'))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
